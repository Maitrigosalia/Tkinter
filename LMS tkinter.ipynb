# %%
from tkinter import * 
root=Tk()
root.title("Arthshila Library")
root.geometry("900x800")
top=Frame(root)
top.pack(side=TOP)
m=Frame(root)
m.pack()
lbl1=Label(top,font=("Times",40,"bold"),text="Welcome to Arthshila Library",fg="Blue",bg="White")
lbl1.pack()

b1=Button(m,font=("Times",18,"bold"),text="Book Management",fg="White",bg="Blue")
b1.grid(row=5,column=5)
b2=Button(m,font=("Times",18,"bold"),text="Issue Management",fg="White",bg="Blue")
b2.grid(row=6,column=5)
b3=Button(m,font=("Times",18,"bold"),text="Member Management",fg="White",bg="Blue")
b3.grid(row=7,column=5)
root.mainloop()

# %%
from tkinter import *
root=Tk()
root.title("Book")
root.geometry("900x800")
top=Frame(root)
top.pack(side=TOP)
m=Frame(root)
m.pack()
def Add():
    Add()
def Display():
    Display()
def Search():
    Display()
def Delete():
    Delete()
def Update():
    Update()
def Return():
    Return()
    
lbl2=Label(top,font=("Times",25,"bold"),text="Book Management",fg="Blue",bg="White")
lbl2.pack()
    
b1=Button(m,font=("Times",18,"bold"),text="Add Book",fg="Black",bg="White",command=Add)
b1.grid(row=5,column=5)  
b2=Button(m,font=("Times",18,"bold"),text="Display Book",fg="Black",bg="White",command=Display)
b2.grid(row=6,column=5)
b3=Button(m,font=("Times",18,"bold"),text="Search Book",fg="Black",bg="White",command=Search)
b3.grid(row=7,column=5)
b4=Button(m,font=("Times",18,"bold"),text="Delete Book",fg="Black",bg="White",command=Delete)
b4.grid(row=8,column=5)
b5=Button(m,font=("Times",18,"bold"),text="Update Book",fg="Black",bg="White",command=Update)
b5.grid(row=9,column=5)
b6=Button(m,font=("Times",18,"bold"),text="Return to main menu",fg="Black",bg="White",command=Return)
b6.grid(row=10,column=5)
root.mainloop()

# %%
from tkinter import *
root=Tk()
root.title("Member")
root.geometry("900x800")
top=Frame(root)
top.pack(side=TOP)
m=Frame(root)
m.pack()
def Add():
    Add()
def Display():
    Display()
def Search():
    Search()
def Delete():
    Delete()
def Update():
    Update()
def Return():
    Return()
lbl2=Label(top,font=("Times",25,"bold"),text="Issue Management",fg="Blue",bg="White")
lbl2.pack()
    
b1=Button(m,font=("Times",18,"bold"),text="Add Member",fg="Black",bg="White",command=Add)
b1.grid(row=5,column=5)  
b2=Button(m,font=("Times",18,"bold"),text="Display Member",fg="Black",bg="White",command=Display)
b2.grid(row=6,column=5)
b3=Button(m,font=("Times",18,"bold"),text="Search Member",fg="Black",bg="White",command=Search)
b3.grid(row=7,column=5)
b4=Button(m,font=("Times",18,"bold"),text="Delete Member",fg="Black",bg="White",command=Delete)
b4.grid(row=8,column=5)
b5=Button(m,font=("Times",18,"bold"),text="Update Member",fg="Black",bg="White",command=Update)
b5.grid(row=9,column=5)
b6=Button(m,font=("Times",18,"bold"),text="Return to main menu",fg="Black",bg="White",command=Return)
b6.grid(row=10,column=5)
root.mainloop()

# %%
from tkinter import *
root=Tk()
root.title("Book")
root.geometry("900x800")
top=Frame(root)
top.pack(side=TOP)
m=Frame(root)
m.pack()
lbl2=Label(top,font=("Times",25,"bold"),text="Member Management",fg="Blue",bg="White")
lbl2.pack()
    
b1=Button(m,font=("Times",18,"bold"),text="Add Book",fg="Black",bg="White",command=Add)
b1.grid(row=5,column=5)  
b2=Button(m,font=("Times",18,"bold"),text="Display Book",fg="Black",bg="White",command=Display)
b2.grid(row=6,column=5)
b3=Button(m,font=("Times",18,"bold"),text="Search Book",fg="Black",bg="White",command=Search)
b3.grid(row=7,column=5)
b4=Button(m,font=("Times",18,"bold"),text="Delete Book",fg="Black",bg="White",command=Delete)
b4.grid(row=8,column=5)
b5=Button(m,font=("Times",18,"bold"),text="Update Book",fg="Black",bg="White",command=Update)
b5.grid(row=9,column=5)
b6=Button(m,font=("Times",18,"bold"),text="Return to main menu",fg="Black",bg="White",command=Return)
b6.grid(row=10,column=5)
root.mainloop()

# %%
from tkinter import *
def add():
    pass
root=Tk()
root.title("book")
root.geometry("900x700")
top=Frame(root)
top.pack(side=TOP)
m=Frame(root)
m.pack()
lbl3=Label(top,font=("Times",30,"bold"),text="Add Book",fg="green",bg="yellow")
lbl3.pack()

id=StringVar()
name=StringVar()
author=StringVar()
price=StringVar()
pname=StringVar()
qut=StringVar()
purchased=StringVar()

l1=Label(m,font=("Times",18),text="Enter book id")
l1.grid(row=10,column=11)
txtid=Entry(m,textvariable=id)
txtid.grid(row=10,column=20)

l1=Label(m,font=("Times",18),text="Enter book name")
l1.grid(row=11,column=11)
txtid=Entry(m,textvariable=name)
txtid.grid(row=11,column=20)

l1=Label(m,font=("Times",18),text="Enter author name")
l1.grid(row=12,column=11)
txtid=Entry(m,textvariable=author)
txtid.grid(row=12,column=20)

l1=Label(m,font=("Times",18),text="Enter book price")
l1.grid(row=13,column=11)
txtid=Entry(m,textvariable=price)
txtid.grid(row=13,column=20)

l1=Label(m,font=("Times",18),text="Enter publisher name")
l1.grid(row=14,column=11)
txtid=Entry(m,textvariable=pname)
txtid.grid(row=14,column=20)

l1=Label(m,font=("Times",18),text="Quantity on hand")
l1.grid(row=15,column=11)
txtid=Entry(m,textvariable=qut)
txtid.grid(row=15,column=20)

l1=Label(m,font=("Times",18),text="Purchased date")
l1.grid(row=16,column=11)
txtid=Entry(m,textvariable=purchased)
txtid.grid(row=16,column=20)

root.mainloop()
